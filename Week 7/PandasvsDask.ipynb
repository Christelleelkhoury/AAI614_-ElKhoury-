# %% [markdown]
# <a href="https://colab.research.google.com/github/Christelleelkhoury/AAI614_-ElKhoury-/blob/main/PandasvsDask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications

# %% [markdown]
# import packages

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import dask.dataframe as dd
import glob
import time
import urllib

import ssl

ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Small dataset

# %%
df_pandas = pd.read_csv('https://raw.githubusercontent.com/Christelleelkhoury/AAI614_-ElKhoury-/refs/heads/main/Week%207/diabetes.csv')

# %%
# %%time
df_pandas.head()
# Out:
# CPU times: user 323 µs, sys: 0 ns, total: 323 µs
# Wall time: 315 µs
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# %%time
df_dask = dd.read_csv('https://raw.githubusercontent.com/Christelleelkhoury/AAI614_-ElKhoury-/refs/heads/main/Week%207/diabetes.csv')
df_dask.head()
# Out:
# CPU times: user 25 ms, sys: 1.98 ms, total: 27 ms
# Wall time: 89 ms
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# [From Kaggle](https://www.kaggle.com/competitions/amex-default-prediction/data?select=sample_submission.csv) Large Dataset

# %%
# !unzip /content/sample_submission.csv.zip
# Out:
# Archive:  /content/sample_submission.csv.zip
#   inflating: sample_submission.csv

# %%
# %%time
df_pandas2 = pd.read_csv('/content/sample_submission.csv')
df_pandas2.head()
# Out:
# CPU times: user 1.74 s, sys: 158 ms, total: 1.9 s
# Wall time: 1.96 s
#                                          customer_ID  prediction
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...           0
# 1  00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...           0
# 2  0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...           0
# 3  00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...           0
# 4  00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...           0

# %%
# %%time
df_dask2 = dd.read_csv('/content/sample_submission.csv')
df_dask2.head()
# Out:
# CPU times: user 1.3 s, sys: 295 ms, total: 1.59 s
# Wall time: 1.61 s
#                                          customer_ID  prediction
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...           0
# 1  00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...           0
# 2  0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...           0
# 3  00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...           0
# 4  00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...           0
